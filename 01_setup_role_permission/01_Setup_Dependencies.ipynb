# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !pip list
# Out:
# Package                              Version
# ------------------------------------ -----------
# aiohappyeyeballs                     2.6.1
# aiohttp                              3.13.2
# aiosignal                            1.4.0
# alembic                              1.17.2
# annotated-doc                        0.0.4
# annotated-types                      0.7.0
# antlr4-python3-runtime               4.9.3
# anyio                                4.12.0
# asttokens                            3.0.1
# attrs                                25.4.0
# awscli                               1.43.6
# awswrangler                          3.14.0
# bcrypt                               5.0.0
# blinker                              1.9.0
# boto3                                1.42.0
# botocore                             1.41.6
# brotli                               1.2.0
# cachetools                           6.2.2
# certifi                              2025.11.12
# cffi                                 2.0.0
# charset-normalizer                   3.4.4
# click                                8.3.1
# cloudpickle                          3.1.2
# colorama                             0.4.6
# coloredlogs                          15.0.1
# comm                                 0.2.3
# contourpy                            1.3.3
# cryptography                         46.0.3
# cycler                               0.12.1
# databricks-sdk                       0.73.0
# debugpy                              1.8.17
# decorator                            5.2.1
# deepdiff                             8.6.1
# docker                               7.1.0
# docutils                             0.19
# executing                            2.2.1
# fastapi                              0.123.0
# filelock                             3.20.0
# Flask                                3.1.2
# flask-cors                           6.0.1
# flatbuffers                          25.9.23
# fonttools                            4.61.0
# frozenlist                           1.8.0
# fsspec                               2025.10.0
# gevent                               25.9.1
# geventhttpclient                     2.3.5
# gitdb                                4.0.12
# GitPython                            3.1.45
# google-auth                          2.43.0
# graphene                             3.4.3
# graphql-core                         3.2.7
# graphql-relay                        3.2.0
# greenlet                             3.2.4
# gunicorn                             23.0.0
# h11                                  0.16.0
# huey                                 2.5.4
# humanfriendly                        10.0
# idna                                 3.11
# importlib-metadata                   6.11.0
# iniconfig                            2.3.0
# invoke                               2.2.1
# ipykernel                            7.1.0
# ipython                              9.7.0
# ipython_pygments_lexers              1.1.1
# ipywidgets                           8.1.8
# itsdangerous                         2.2.0
# jedi                                 0.19.2
# Jinja2                               3.1.6
# jmespath                             1.0.1
# joblib                               1.5.2
# json5                                0.12.1
# jsonschema                           4.25.1
# jsonschema-specifications            2025.9.1
# jupyter_client                       8.6.3
# jupyter_core                         5.9.1
# jupyterlab_widgets                   3.0.16
# kiwisolver                           1.4.9
# Mako                                 1.3.10
# markdown-it-py                       4.0.0
# MarkupSafe                           3.0.3
# matplotlib                           3.10.7
# matplotlib-inline                    0.2.1
# mdurl                                0.1.2
# ml_dtypes                            0.5.4
# mlflow                               3.6.0
# mlflow-skinny                        3.6.0
# mlflow-tracing                       3.6.0
# mock                                 4.0.3
# mpmath                               1.3.0
# multidict                            6.7.0
# nest_asyncio                         1.6.0
# networkx                             3.6
# numpy                                2.3.5
# nvidia-cublas-cu12                   12.8.4.1
# nvidia-cuda-cupti-cu12               12.8.90
# nvidia-cuda-nvrtc-cu12               12.8.93
# nvidia-cuda-runtime-cu12             12.8.90
# nvidia-cudnn-cu12                    9.10.2.21
# nvidia-cufft-cu12                    11.3.3.83
# nvidia-cufile-cu12                   1.13.1.3
# nvidia-curand-cu12                   10.3.9.90
# nvidia-cusolver-cu12                 11.7.3.90
# nvidia-cusparse-cu12                 12.5.8.93
# nvidia-cusparselt-cu12               0.7.1
# nvidia-nccl-cu12                     2.27.5
# nvidia-nvjitlink-cu12                12.8.93
# nvidia-nvshmem-cu12                  3.3.20
# nvidia-nvtx-cu12                     12.8.90
# omegaconf                            2.3.0
# onnx                                 1.19.1
# onnxruntime                          1.23.2
# opentelemetry-api                    1.38.0
# opentelemetry-proto                  1.27.0
# opentelemetry-sdk                    1.38.0
# opentelemetry-semantic-conventions   0.59b0
# orderly-set                          5.5.0
# packaging                            25.0
# pandas                               2.3.3
# paramiko                             4.0.0
# parso                                0.8.5
# perf_analyzer                        0.1.0
# pexpect                              4.9.0
# pillow                               12.0.0
# pip                                  25.3
# platformdirs                         4.5.0
# pluggy                               1.6.0
# prompt_toolkit                       3.0.52
# propcache                            0.4.1
# protobuf                             4.25.8
# psutil                               7.1.3
# psycopg2-binary                      2.9.11
# ptyprocess                           0.7.0
# pure_eval                            0.2.3
# pyarrow                              21.0.0
# pyasn1                               0.6.1
# pyasn1_modules                       0.4.2
# PyAthena                             3.22.0
# pycparser                            2.23
# pydantic                             2.12.5
# pydantic_core                        2.41.5
# Pygments                             2.19.2
# pyinstrument                         3.4.2
# pyinstrument_cext                    0.2.4
# PyNaCl                               1.6.1
# pyparsing                            3.2.5
# pytest                               9.0.1
# python-dateutil                      2.9.0.post0
# python-dotenv                        1.2.1
# python-rapidjson                     1.22
# pytz                                 2025.2
# PyYAML                               6.0.3
# pyzmq                                27.1.0
# referencing                          0.37.0
# requests                             2.32.5
# rich                                 13.9.4
# rpds-py                              0.30.0
# rsa                                  4.7.2
# s3transfer                           0.16.0
# sagemaker                            3.0.1
# sagemaker-core                       2.0.1
# sagemaker-experiments                0.1.45
# sagemaker-mlflow                     0.1.1
# sagemaker-mlops                      1.0
# sagemaker-schema-inference-artifacts 0.0.5
# sagemaker-serve                      1.0
# sagemaker-train                      1.0
# schema                               0.7.8
# scikit-learn                         1.7.2
# scipy                                1.16.3
# seaborn                              0.13.2
# setuptools                           80.9.0
# six                                  1.17.0
# smdebug-rulesconfig                  1.0.1
# smmap                                5.0.2
# SQLAlchemy                           2.0.44
# sqlparse                             0.5.4
# stack_data                           0.6.3
# starlette                            0.50.0
# stepfunctions                        2.0.0rc1
# sympy                                1.14.0
# tblib                                3.2.2
# tenacity                             9.1.2
# threadpoolctl                        3.6.0
# torch                                2.9.1
# tornado                              6.5.2
# tqdm                                 4.67.1
# traitlets                            5.14.3
# triton                               3.5.1
# tritonclient                         2.63.0
# typing_extensions                    4.15.0
# typing-inspection                    0.4.2
# tzdata                               2025.2
# urllib3                              2.5.0
# uvicorn                              0.38.0
# wcwidth                              0.2.14
# Werkzeug                             3.1.4
# wheel                                0.45.1
# widgetsnbextension                   4.0.15
# wrapt                                2.0.1
# yarl                                 1.22.0
# zipp                                 3.23.0
# zope.event                           6.1
# zope.interface                       8.1.1

# %% [markdown]
# # Setup pip

# %%
# !pip install --disable-pip-version-check -q pip --upgrade > /dev/null
# !pip install --disable-pip-version-check -q wrapt --upgrade > /dev/null

# %% [markdown]
# # Setup AWS

# %%
# !pip install -U awscli boto3 botocore
# Out:
# Requirement already satisfied: awscli in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (1.43.6)
# Requirement already satisfied: boto3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (1.42.0)
# Requirement already satisfied: botocore in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (1.41.6)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from awscli) (0.19)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from awscli) (0.16.0)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from awscli) (6.0.3)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from awscli) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from awscli) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from botocore) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from botocore) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.1)

# %%
# !pip install "sagemaker>=2,<3" "protobuf==3.20.3"
# Out:
# Collecting sagemaker<3,>=2
#   Downloading sagemaker-2.254.1-py3-none-any.whl.metadata (17 kB)
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: attrs<26,>=24 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (25.4.0)
# Requirement already satisfied: boto3<2.0,>=1.39.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (1.42.0)
# Requirement already satisfied: cloudpickle>=2.2.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (3.1.2)
# Requirement already satisfied: docker in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (7.1.0)
# Requirement already satisfied: fastapi in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (0.123.0)
# Collecting google-pasta (from sagemaker<3,>=2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: graphene<4,>=3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (3.4.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (6.11.0)
# Requirement already satisfied: jsonschema in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (4.25.1)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (2.3.5)
# Requirement already satisfied: omegaconf<3,>=2.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (2.3.0)
# Collecting packaging<25,>=23.0 (from sagemaker<3,>=2)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas>=2.3.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (2.3.3)
# Collecting pathos (from sagemaker<3,>=2)
#   Downloading pathos-0.3.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (4.5.0)
# Requirement already satisfied: psutil in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (7.1.3)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (6.0.3)
# Requirement already satisfied: requests in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (2.32.5)
# Collecting sagemaker-core<2.0.0,>=1.0.17 (from sagemaker<3,>=2)
#   Downloading sagemaker_core-1.0.69-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: schema in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (0.7.8)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (3.2.2)
# Requirement already satisfied: tqdm in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (4.67.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (2.5.0)
# Requirement already satisfied: uvicorn in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker<3,>=2) (0.38.0)
# Requirement already satisfied: botocore<1.42.0,>=1.41.6 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3<2.0,>=1.39.5->sagemaker<3,>=2) (1.41.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3<2.0,>=1.39.5->sagemaker<3,>=2) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3<2.0,>=1.39.5->sagemaker<3,>=2) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from botocore<1.42.0,>=1.41.6->boto3<2.0,>=1.39.5->sagemaker<3,>=2) (2.9.0.post0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3,>=2) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3,>=2) (3.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3,>=2) (4.15.0)
# Requirement already satisfied: zipp>=0.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker<3,>=2) (3.23.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from omegaconf<3,>=2.2->sagemaker<3,>=2) (4.9.3)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.6->boto3<2.0,>=1.39.5->sagemaker<3,>=2) (1.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (2.12.5)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from jsonschema->sagemaker<3,>=2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from jsonschema->sagemaker<3,>=2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from jsonschema->sagemaker<3,>=2) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3,>=2) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pandas>=2.3.0->sagemaker<3,>=2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pandas>=2.3.0->sagemaker<3,>=2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests->sagemaker<3,>=2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests->sagemaker<3,>=2) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests->sagemaker<3,>=2) (2025.11.12)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from fastapi->sagemaker<3,>=2) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from fastapi->sagemaker<3,>=2) (0.0.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi->sagemaker<3,>=2) (4.12.0)
# Collecting ppft>=1.7.7 (from pathos->sagemaker<3,>=2)
#   Downloading ppft-1.7.7-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.4.0 (from pathos->sagemaker<3,>=2)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.6 (from pathos->sagemaker<3,>=2)
#   Downloading pox-0.3.6-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.18 (from pathos->sagemaker<3,>=2)
#   Downloading multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=7.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from uvicorn->sagemaker<3,>=2) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from uvicorn->sagemaker<3,>=2) (0.16.0)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Downloading sagemaker-2.254.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.5 MB/s  0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading sagemaker_core-1.0.69-py3-none-any.whl (433 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading pathos-0.3.4-py3-none-any.whl (82 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
# Downloading pox-0.3.6-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.7-py3-none-any.whl (56 kB)
# Installing collected packages: protobuf, ppft, pox, packaging, google-pasta, dill, multiprocess, pathos, sagemaker-core, sagemaker
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
#   Attempting uninstall: packaging━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [ppft]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━  1/10 [ppft]
#     Uninstalling packaging-25.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [ppft]
#       Successfully uninstalled packaging-25.0━━━━━━━━━━━━━━━━━  1/10 [ppft]
#   Attempting uninstall: sagemaker-core90m╺━━━━━━━━━━━━━━━  6/10 [multiprocess]
#     Found existing installation: sagemaker-core 2.0.1━━━━━━━━━  6/10 [multiprocess]
#     Uninstalling sagemaker-core-2.0.1:━━━━━━━━━━━━━━━  6/10 [multiprocess]
#       Successfully uninstalled sagemaker-core-2.0.1━━━━━━━━━━━  6/10 [multiprocess]
#   Attempting uninstall: sagemaker━━━━━━━╺━━━━━━━  8/10 [sagemaker-core]
#     Found existing installation: sagemaker 3.0.10m━━━━━━━  8/10 [sagemaker-core]
#     Uninstalling sagemaker-3.0.1:━━━╺━━━━━━━  8/10 [sagemaker-core]
#       Successfully uninstalled sagemaker-3.0.1━━━━━━━  8/10 [sagemaker-core]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [sagemaker]10 [sagemaker]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnx 1.19.1 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# databricks-sdk 0.73.0 requires protobuf!=5.26.*,!=5.27.*,!=5.28.*,!=5.29.0,!=5.29.1,!=5.29.2,!=5.29.3,!=5.29.4,!=6.30.0,!=6.30.1,!=6.31.0,<7.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# sagemaker-train 1.0 requires sagemaker-core>=2.0.0, but you have sagemaker-core 1.0.69 which is incompatible.
# sagemaker-serve 1.0 requires sagemaker-core>=2.0.0, but you have sagemaker-core 1.0.69 which is incompatible.
# sagemaker-mlops 1.0 requires sagemaker-core>=2.0.0, but you have sagemaker-core 1.0.69 which is incompatible.
# Successfully installed dill-0.4.0 google-pasta-0.2.0 multiprocess-0.70.18 packaging-24.2 pathos-0.3.4 pox-0.3.6 ppft-1.7.7 protobuf-3.20.3 sagemaker-2.254.1 sagemaker-core-1.0.69

# %%
# !pip install -U mlflow sagemaker-mlflow
# Out:
# Requirement already satisfied: mlflow in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: sagemaker-mlflow in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: Flask<4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (2.5.4)
# Requirement already satisfied: matplotlib<4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: numpy<3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (2.3.5)
# Requirement already satisfied: pandas<3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.73.0)
# Requirement already satisfied: fastapi<1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.123.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.11.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: packaging<26 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.25.8)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.43.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.7.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.12.0)
# Requirement already satisfied: h11>=0.8 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: boto3>=1.34 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from sagemaker-mlflow) (1.42.0)
# Requirement already satisfied: botocore<1.42.0,>=1.41.6 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow) (1.41.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from boto3>=1.34->sagemaker-mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)

# %% [markdown]
# # Setup others

# %%
# !pip install --disable-pip-version-check -q PyAthena
# !pip install --disable-pip-version-check -q SQLAlchemy
# !pip install --disable-pip-version-check -q psycopg2-binary
# !pip install --disable-pip-version-check -q awswrangler
# !pip install --disable-pip-version-check -q stepfunctions==2.0.0rc1
# !conda install -y zip
# !pip install --disable-pip-version-check -q matplotlib
# !pip install --disable-pip-version-check -q seaborn
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - zip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-25.11.0              |  py312h7900ff3_0         1.2 MB  conda-forge
#     zip-3.0                    |       hd590300_3         173 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   zip                conda-forge/linux-64::zip-3.0-hd590300_3
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.10.5-hbd8a1cb_0 --> 2025.11.12-hbd8a1cb_0
#   certifi                            2025.10.5-pyhd8ed1ab_0 --> 2025.11.12-pyhd8ed1ab_0
#   conda                              25.9.1-py312h7900ff3_0 --> 25.11.0-py312h7900ff3_0
#
#
#
# Downloading and Extracting Packages:
# conda-25.11.0        | 1.2 MB    |                                       |   0%
# zip-3.0              | 173 KB    |                                       |   0%
#
# conda-25.11.0        | 1.2 MB    | ##################################### | 100%
#
# certifi-2025.11.12   | 153 KB    | ###8                                  |  10%
#
# certifi-2025.11.12   | 153 KB    | ##################################### | 100%
# zip-3.0              | 173 KB    | ###4                                  |   9%
# zip-3.0              | 173 KB    | ##################################### | 100%
#
# certifi-2025.11.12   | 153 KB    | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
setup_dependencies_passed = True
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed             -> True
